# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('/content/drive/MyDrive/ObesityDataSet_raw_and_data_sinthetic.csv')
data.head(10)
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
# 5    Male  29.0    1.62    53.0                             no  yes   2.0
# 6  Female  23.0    1.50    55.0                            yes  yes   3.0
# 7    Male  22.0    1.64    53.0                             no   no   2.0
# 8    Male  24.0    1.78    64.0                            yes  yes   3.0
# 9    Male  22.0    1.72    68.0                            yes  yes   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
# 5  3.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
# 6  3.0  Sometimes    no   2.0   no  1.0  0.0   Sometimes
# 7  3.0  Sometimes    no   2.0   no  3.0  0.0   Sometimes
# 8  3.0  Sometimes    no   2.0   no  1.0  1.0  Frequently
# 9  3.0  Sometimes    no   2.0   no  1.0  1.0          no
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# 2  Public_Transportation        Normal_Weight
# 3                Walking   Overweight_Level_I
# 4  Public_Transportation  Overweight_Level_II
# 5             Automobile        Normal_Weight
# 6              Motorbike        Normal_Weight
# 7  Public_Transportation        Normal_Weight
# 8  Public_Transportation        Normal_Weight
# 9  Public_Transportation        Normal_Weight

# %%
X = data.drop('NObeyesdad', axis = 1)
y = data['NObeyesdad']

X_test, X_temp, y_test, y_temp = train_test_split(X, y, test_size=0.7, random_state=42)

# %%
sns.barplot(data=data['CAEC']).set(title="Do you eat any food between meals?")
# Out:
# [Text(0.5, 1.0, 'Do you eat any food between meals?')]

# %%
sns.barplot(data=data['CALC']).set(title="How often do you drink alcohol?")
# Out:
# [Text(0.5, 1.0, 'How often do you drink alcohol?')]

# %%
sns.barplot(data=data['MTRANS']).set(title="Which transportation do you usually use?")
# Out:
# [Text(0.5, 1.0, 'Which transportation do you usually use?')]

# %%
sns.barplot(data=data['NObeyesdad']).set(title="Obesity level")
# Out:
# [Text(0.5, 1.0, 'Obesity level')]

# %%
sns.barplot(data=data['family_history_with_overweight']).set(title="Has a family member suffered or suffers from overweight?", xlabel = "count", ylabel="answer")
# Out:
# [Text(0.5, 1.0, 'Has a family member suffered or suffers from overweight?'),
#  Text(0.5, 0, 'count'),
#  Text(0, 0.5, 'answer')]

# %%
sns.barplot(data=data['FAVC']).set(title="Do you eat high caloric food frequently?")
# Out:
# [Text(0.5, 1.0, 'Do you eat high caloric food frequently?')]

# %%
sns.barplot(data=data['SMOKE']).set(title="Do you smoke?")
# Out:
# [Text(0.5, 1.0, 'Do you smoke?')]

# %%
sns.barplot(data=data['SCC']).set(title="Do you monitor the calories you eat daily?")
# Out:
# [Text(0.5, 1.0, 'Do you monitor the calories you eat daily?')]

# %%
sns.histplot(data=data['Age']).set(title="Age")
# Out:
# [Text(0.5, 1.0, 'Age')]

# %%
sns.histplot(data=data['Weight']).set(title="Histogram of weight", xlabel = "weight", ylabel="count")
# Out:
# [Text(0.5, 1.0, 'Histogram of weight'),
#  Text(0.5, 0, 'weight'),
#  Text(0, 0.5, 'count')]

# %%
sns.histplot(data=data['Height']).set(title="Height")
# Out:
# [Text(0.5, 1.0, 'Height')]

# %%
sns.histplot(data=data['FCVC']).set(title="Do you usually eat vegetables in your meals?")
# Out:
# [Text(0.5, 1.0, 'Do you usually eat vegetables in your meals?')]

# %%
sns.histplot(data=data['NCP']).set(title="How many main meals do you have daily?", xlabel = 'number of meals', ylabel='count')
# Out:
# [Text(0.5, 1.0, 'How many main meals do you have daily?'),
#  Text(0.5, 0, 'number of meals'),
#  Text(0, 0.5, 'count')]

# %%
sns.histplot(data=data['CH2O']).set(title="How much water do you drink daily?")
# Out:
# [Text(0.5, 1.0, 'How much water do you drink daily?')]

# %%
sns.histplot(data=data['FAF']).set(title="How often do you have physical activity?")
# Out:
# [Text(0.5, 1.0, 'How often do you have physical activity?')]

# %%
sns.histplot(data=data['TUE']).set(title="How much time do you use technological devices?")
# Out:
# [Text(0.5, 1.0, 'How much time do you use technological devices?')]

# %%
plt.figure(figsize=(15, 5))
sns.boxplot(x=data['NObeyesdad'], y=data['Weight']).set(title="?")
# Out:
# [Text(0.5, 1.0, '?')]

# %%
plt.figure(figsize=(15, 5))
sns.boxplot(x=data['NObeyesdad'], y=data['Height']).set(title="?")
# Out:
# [Text(0.5, 1.0, '?')]

# %%
plt.figure(figsize=(15, 5))
sns.boxplot(x=data['CAEC'], y=data['Weight']).set(title="Weight vs Do you eat any food between meals?")
# Out:
# [Text(0.5, 1.0, 'Weight vs Do you eat any food between meals?')]

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(x=data['Weight'], y=data['Height'], hue=data['NObeyesdad']).set(title="Scatter plot with height and weight")
# Out:
# [Text(0.5, 1.0, 'Scatter plot with height and weight')]

# %%
"""
goal: Estimate how often do you have physical activity (FAF)

features: FAVC, FCVC, CAEC, CH2O, SCC, CALC, SMOKE, Weight

"""
# Out:
# '\ngoal: Estimate how often do you have physical activity (FAF)\n\nfeatures: FAVC, FCVC, CAEC, CH2O, SCC, CALC, SMOKE, Weight\n\n'

# %%
sns.scatterplot(x=data['FAF'], y=data['CH2O']).set(title="How often do you have physical activity in compasion to frequency of drinking water", xlabel = "physical activity", ylabel="water consumption")
# Out:
# [Text(0.5, 1.0, 'How often do you have physical activity in compasion to frequency of drinking water'),
#  Text(0.5, 0, 'physical activity'),
#  Text(0, 0.5, 'water consumption')]

# %%
xpp = data['FAF']
xpp.head()
# Out:
# 0    0.0
# 1    3.0
# 2    2.0
# 3    2.0
# 4    0.0
# Name: FAF, dtype: float64

# %%
data['FAF'].value_counts()
# Out:
# FAF
# 0.000000    411
# 1.000000    234
# 2.000000    183
# 3.000000     75
# 0.110174      2
#            ...
# 1.916751      1
# 0.954459      1
# 0.340915      1
# 0.986414      1
# 1.026452      1
# Name: count, Length: 1190, dtype: int64

# %%
data_filtered = data[data['FAF'].isin([0, 1, 2, 3])]

# %%
data_filtered['FAF'].value_counts()
# Out:
# FAF
# 0.0    411
# 1.0    234
# 2.0    183
# 3.0     75
# Name: count, dtype: int64

# %%
X = data.drop('NObeyesdad', axis = 1)
y = data['NObeyesdad']

X_test, X_temp, y_test, y_temp = train_test_split(X, y, test_size=0.7, random_state=42)

# %%
data = data.drop(columns=["Gender", "CAEC", "CALC", "MTRANS", "NObeyesdad", "family_history_with_overweight", "FAVC", "SMOKE", "SCC"])
data
# Out:
#             Age    Height      Weight  FCVC  NCP      CH2O       FAF       TUE
# 0     21.000000  1.620000   64.000000   2.0  3.0  2.000000  0.000000  1.000000
# 1     21.000000  1.520000   56.000000   3.0  3.0  3.000000  3.000000  0.000000
# 2     23.000000  1.800000   77.000000   2.0  3.0  2.000000  2.000000  1.000000
# 3     27.000000  1.800000   87.000000   3.0  3.0  2.000000  2.000000  0.000000
# 4     22.000000  1.780000   89.800000   2.0  1.0  2.000000  0.000000  0.000000
# ...         ...       ...         ...   ...  ...       ...       ...       ...
# 2106  20.976842  1.710730  131.408528   3.0  3.0  1.728139  1.676269  0.906247
# 2107  21.982942  1.748584  133.742943   3.0  3.0  2.005130  1.341390  0.599270
# 2108  22.524036  1.752206  133.689352   3.0  3.0  2.054193  1.414209  0.646288
# 2109  24.361936  1.739450  133.346641   3.0  3.0  2.852339  1.139107  0.586035
# 2110  23.664709  1.738836  133.472641   3.0  3.0  2.863513  1.026452  0.714137
#
# [2111 rows x 8 columns]

# %%
sns.set_theme(rc={'figure.figsize':(10, 5)})
corr = data.corr()
sns.heatmap(corr, cmap = 'coolwarm', annot = True)
# Out:
# <Axes: >
